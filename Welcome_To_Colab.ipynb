# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week12/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
def calculate_rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)
    return (area, perimeter)

# PROGRAM LOGIC
length = float(input("Enter length: "))
width = float(input("Enter width: "))

my_area, my_perimeter = calculate_rectangle(length, width)

print("\n--- Results ---")
print("The Area is:", my_area)
print("The Perimeter is:", my_perimeter)
# Out:
# Enter length: 10
# Enter width: 5
#
# --- Results ---
# The Area is: 50.0
# The Perimeter is: 30.0
